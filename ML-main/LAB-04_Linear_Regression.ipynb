# %% [markdown]
# <a href="https://colab.research.google.com/github/Sagar122198/ML/blob/main/LAB%2004%20Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# np.random.seed(42)
#
# X = np.random.rand(50, 1) * 100

# %%
X
# Out:
# array([[37.45401188],
#        [95.07143064],
#        [73.19939418],
#        [59.86584842],
#        [15.60186404],
#        [15.59945203],
#        [ 5.80836122],
#        [86.61761458],
#        [60.11150117],
#        [70.80725778],
#        [ 2.05844943],
#        [96.99098522],
#        [83.24426408],
#        [21.23391107],
#        [18.18249672],
#        [18.34045099],
#        [30.4242243 ],
#        [52.47564316],
#        [43.19450186],
#        [29.12291402],
#        [61.18528947],
#        [13.94938607],
#        [29.21446485],
#        [36.63618433],
#        [45.60699842],
#        [78.51759614],
#        [19.96737822],
#        [51.42344384],
#        [59.24145689],
#        [ 4.64504127],
#        [60.75448519],
#        [17.05241237],
#        [ 6.5051593 ],
#        [94.88855373],
#        [96.56320331],
#        [80.83973481],
#        [30.46137692],
#        [ 9.7672114 ],
#        [68.42330265],
#        [44.01524937],
#        [12.20382348],
#        [49.51769101],
#        [ 3.43885211],
#        [90.93204021],
#        [25.87799816],
#        [66.25222844],
#        [31.17110761],
#        [52.00680212],
#        [54.67102793],
#        [18.48544555]])

# %%
np.random.seed(42)

X = np.random.rand(1000, 20) * 100

# %%
X
# Out:
# array([[37.45401188],
#        [95.07143064],
#        [73.19939418],
#        [59.86584842],
#        [15.60186404],
#        [15.59945203],
#        [ 5.80836122],
#        [86.61761458],
#        [60.11150117],
#        [70.80725778],
#        [ 2.05844943],
#        [96.99098522],
#        [83.24426408],
#        [21.23391107],
#        [18.18249672],
#        [18.34045099],
#        [30.4242243 ],
#        [52.47564316],
#        [43.19450186],
#        [29.12291402],
#        [61.18528947],
#        [13.94938607],
#        [29.21446485],
#        [36.63618433],
#        [45.60699842],
#        [78.51759614],
#        [19.96737822],
#        [51.42344384],
#        [59.24145689],
#        [ 4.64504127],
#        [60.75448519],
#        [17.05241237],
#        [ 6.5051593 ],
#        [94.88855373],
#        [96.56320331],
#        [80.83973481],
#        [30.46137692],
#        [ 9.7672114 ],
#        [68.42330265],
#        [44.01524937],
#        [12.20382348],
#        [49.51769101],
#        [ 3.43885211],
#        [90.93204021],
#        [25.87799816],
#        [66.25222844],
#        [31.17110761],
#        [52.00680212],
#        [54.67102793],
#        [18.48544555]])

# %%
Y = 3.5 * X + np.random.randn(50, 1) * 20

# %%
Y
# Out:
# array([[145.8583732 ],
#        [336.17737287],
#        [253.88491399],
#        [203.50839556],
#        [ 25.03608435],
#        [ 40.20119795],
#        [ 11.11648884],
#        [324.30409555],
#        [217.2626199 ],
#        [212.56459912],
#        [ 13.68625239],
#        [331.76680265],
#        [277.81648427],
#        [ 86.55221451],
#        [ 84.25872897],
#        [ 82.81718083],
#        [ 89.70043457],
#        [177.48050355],
#        [157.80602515],
#        [121.44110161],
#        [204.5650284 ],
#        [ 45.10967169],
#        [ 80.12392751],
#        [104.30251267],
#        [175.87501092],
#        [301.93638706],
#        [ 68.44562132],
#        [200.0527114 ],
#        [214.5778196 ],
#        [  3.35524936],
#        [219.86861028],
#        [ 90.44417462],
#        [ 22.05153676],
#        [363.40281115],
#        [285.57630949],
#        [299.37712193],
#        [108.35576058],
#        [ 28.20509289],
#        [241.31677481],
#        [114.30199452],
#        [ 38.31994444],
#        [180.45416997],
#        [ 41.59386329],
#        [307.89673636],
#        [ 74.4031215 ],
#        [221.84765865],
#        [127.40691899],
#        [188.59882961],
#        [180.75339369],
#        [ 74.9644081 ]])

# %%
import pandas as pd
import numpy as np

# Ensure Y has the same number of samples as X
# If X has changed its number of samples, Y needs to be re-generated accordingly.
# Assuming Y is intended to be generated from a single feature of X, plus noise
if X.shape[0] != Y.shape[0]:
    # Use the first feature of X for generating Y, maintaining the original relationship structure
    Y = 3.5 * X[:, 0].reshape(-1, 1) + np.random.randn(X.shape[0], 1) * 20

# Now, create the DataFrame for plotting. We'll plot the first feature of X against Y.
data = {'X': X[:, 0], 'Y': Y.flatten()}
df = pd.DataFrame(data)
df.plot(x ='X', y='Y', kind = 'scatter')
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
Y_pred = model.predict(X[:, 0].reshape(-1, 1)) # Calculate predictions using the fitted model with the first feature of X

plt.figure(figsize=(8,6))
plt.scatter(X[:, 0], Y, color='blue', label='Data Points') # Plot the first feature of X against Y
plt.plot(X[:, 0], Y_pred, color='red', linewidth=2, label='Regression Line') # Plot the first feature of X against Y_pred
plt.title('Linear Regression on Random Dataset')
plt.xlabel('X (first feature)')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()

# %%
print("Slope (Coefficient):", model.coef_[0][0])
print("Intercept:", model.intercept_[0])
# Out:
# Slope (Coefficient): 3.4875531931891217
# Intercept: 1.2525368558421235

# %%
model = LinearRegression()
model.fit(X[:, 0].reshape(-1, 1), Y)
# Out:
# LinearRegression()
